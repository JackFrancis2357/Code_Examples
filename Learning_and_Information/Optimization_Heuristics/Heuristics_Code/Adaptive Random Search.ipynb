# %%
"""
Adaptive Random Search
"""

def objective_function(v):
    return sum(map(lambda x: x ** 2, v))


def rand_in_bounds(min_value, max_value):
    import random
    return min_value + (max_value - min_value) * random.random()


def random_vector(min_max):
    return map(lambda x: rand_in_bounds(x[0], x[1]), min_max)


def take_step(min_max, current, step_size):
    return map(lambda x, y: rand_in_bounds(max(x[0], y - step_size), min(x[1], y + step_size)), min_max, current)


def large_step_size(iteration, step_size, s_factor, l_factor, iteration_multiply):
    if iteration % iteration_multiply == 0:
        return step_size * l_factor
    return step_size * s_factor


def take_steps(bounds, current, step_size, big_step_size):
    step, big_step = {}, {}
    step['vector'] = take_step(bounds, current['vector'], step_size)
    step['cost'] = objective_function(step['vector'])
    big_step['vector'] = take_step(bounds, current['vector'], big_step_size)
    big_step['cost'] = objective_function(big_step['vector'])
    return step, big_step


def search(max_iteration, bounds, init_factor, s_factor, l_factor, iteration_multiply, max_no_impr):
    step_size = (bounds[0][1] - bounds[0][0]) * init_factor
    #print bounds[0][1]
    #print bounds[0][0]

    current, count = {}, 0
    current['vector'] = random_vector(bounds)
    current['cost'] = objective_function(current['vector'])
    for iteration in range(0, max_iteration):
        big_step_size = large_step_size(iteration, step_size, s_factor, l_factor, iteration_multiply)
        step, big_step = take_steps(bounds, current, step_size, big_step_size)
        if step['cost'] <= current['cost'] or big_step['cost'] <= current['cost']:
            if big_step['cost'] <= step['cost']:
                step_size, current = big_step_size, big_step
            else:
                current = step
            count = 0
        else:
            count += 1
            if count >= max_no_impr:
                count, step_size = 0, (step_size / s_factor)
        print(' > iteration=%d, best=%f' % (iteration + 1, current['cost']))
    return current


def main():
    #
    problem_size = 2
    bounds = [[-5, 5]] * problem_size
    #
    max_iteration = 1000
    init_factor = 0.05
    s_factor = 1.3
    l_factor = 3.0
    iteration_multiply = 10
    max_no_improve = 30
    #
    best = search(max_iteration, bounds, init_factor, s_factor, l_factor, iteration_multiply, max_no_improve)
    print('Done. Best Solution: c=%f, v=%s' % (best['cost'], str(best['vector'])))


if __name__ == "__main__":
    main()
# Out:
#  > iteration=1, best=14.004145
#  > iteration=2, best=14.004145
#  > iteration=3, best=10.618098
#  > iteration=4, best=8.003774
#  > iteration=5, best=5.996211
#  > iteration=6, best=4.363072
#  > iteration=7, best=4.363072
#  > iteration=8, best=3.024376
#  > iteration=9, best=3.024376
#  > iteration=10, best=1.552583
#  > iteration=11, best=0.952024
#  > iteration=12, best=0.952024
#  > iteration=13, best=0.147486
#  > iteration=14, best=0.147486
#  > iteration=15, best=0.147486
#  > iteration=16, best=0.147486
#  > iteration=17, best=0.147486
#  > iteration=18, best=0.102421
#  > iteration=19, best=0.102421
#  > iteration=20, best=0.098581
#  > iteration=21, best=0.098581
#  > iteration=22, best=0.098581
#  > iteration=23, best=0.098581
#  > iteration=24, best=0.098581
#  > iteration=25, best=0.098581
#  > iteration=26, best=0.028519
#  > iteration=27, best=0.028519
#  > iteration=28, best=0.028519
#  > iteration=29, best=0.028519
#  > iteration=30, best=0.028519
#  > iteration=31, best=0.028519
#  > iteration=32, best=0.028519
#  > iteration=33, best=0.028519
#  > iteration=34, best=0.028519
#  > iteration=35, best=0.028519
#  > iteration=36, best=0.028519
#  > iteration=37, best=0.028519
#  > iteration=38, best=0.028519
#  > iteration=39, best=0.028519
#  > iteration=40, best=0.028519
#  > iteration=41, best=0.028519
#  > iteration=42, best=0.028519
#  > iteration=43, best=0.028519
#  > iteration=44, best=0.028519
#  > iteration=45, best=0.028519
#  > iteration=46, best=0.028519
#  > iteration=47, best=0.028519
#  > iteration=48, best=0.028519
#  > iteration=49, best=0.028519
#  > iteration=50, best=0.028519
#  > iteration=51, best=0.028519
#  > iteration=52, best=0.028519
#  > iteration=53, best=0.028519
#  > iteration=54, best=0.028519
#  > iteration=55, best=0.028519
#  > iteration=56, best=0.028519
#  > iteration=57, best=0.028519
#  > iteration=58, best=0.028519
#  > iteration=59, best=0.028519
#  > iteration=60, best=0.028519
#  > iteration=61, best=0.028519
#  > iteration=62, best=0.028519
#  > iteration=63, best=0.028519
#  > iteration=64, best=0.028519
#  > iteration=65, best=0.028519
#  > iteration=66, best=0.007129
#  > iteration=67, best=0.007129
#  > iteration=68, best=0.007129
#  > iteration=69, best=0.007129
#  > iteration=70, best=0.007129
#  > iteration=71, best=0.007129
#  > iteration=72, best=0.007129
#  > iteration=73, best=0.007129
#  > iteration=74, best=0.007129
#  > iteration=75, best=0.007129
#  > iteration=76, best=0.007129
#  > iteration=77, best=0.007129
#  > iteration=78, best=0.007129
#  > iteration=79, best=0.007129
#  > iteration=80, best=0.007129
#  > iteration=81, best=0.007129
#  > iteration=82, best=0.007129
#  > iteration=83, best=0.007129
#  > iteration=84, best=0.007129
#  > iteration=85, best=0.007129
#  > iteration=86, best=0.007129
#  > iteration=87, best=0.007129
#  > iteration=88, best=0.007129
#  > iteration=89, best=0.007129
#  > iteration=90, best=0.007129
#  > iteration=91, best=0.007129
#  > iteration=92, best=0.007129
#  > iteration=93, best=0.007129
#  > iteration=94, best=0.007129
#  > iteration=95, best=0.007129
#  > iteration=96, best=0.007129
#  > iteration=97, best=0.007129
#  > iteration=98, best=0.007129
#  > iteration=99, best=0.007129
#  > iteration=100, best=0.007129
#  > iteration=101, best=0.007129
#  > iteration=102, best=0.007129
#  > iteration=103, best=0.007129
#  > iteration=104, best=0.007129
#  > iteration=105, best=0.007129
#  > iteration=106, best=0.007129
#  > iteration=107, best=0.007129
#  > iteration=108, best=0.007129
#  > iteration=109, best=0.007129
#  > iteration=110, best=0.007129
#  > iteration=111, best=0.007129
#  > iteration=112, best=0.007129
#  > iteration=113, best=0.007129
#  > iteration=114, best=0.007129
#  > iteration=115, best=0.007129
#  > iteration=116, best=0.007129
#  > iteration=117, best=0.007129
#  > iteration=118, best=0.007129
#  > iteration=119, best=0.007129
#  > iteration=120, best=0.007129
#  > iteration=121, best=0.007129
#  > iteration=122, best=0.007129
#  > iteration=123, best=0.007129
#  > iteration=124, best=0.007129
#  > iteration=125, best=0.007129
#  > iteration=126, best=0.007129
#  > iteration=127, best=0.007129
#  > iteration=128, best=0.007129
#  > iteration=129, best=0.007129
#  > iteration=130, best=0.007129
#  > iteration=131, best=0.007129
#  > iteration=132, best=0.007129
#  > iteration=133, best=0.007129
#  > iteration=134, best=0.007129
#  > iteration=135, best=0.007129
#  > iteration=136, best=0.007129
#  > iteration=137, best=0.007129
#  > iteration=138, best=0.007129
#  > iteration=139, best=0.007129
#  > iteration=140, best=0.007129
#  > iteration=141, best=0.007129
#  > iteration=142, best=0.007129
#  > iteration=143, best=0.007129
#  > iteration=144, best=0.007129
#  > iteration=145, best=0.007129
#  > iteration=146, best=0.002721
#  > iteration=147, best=0.002721
#  > iteration=148, best=0.002721
#  > iteration=149, best=0.002721
#  > iteration=150, best=0.002721
#  > iteration=151, best=0.002721
#  > iteration=152, best=0.002721
#  > iteration=153, best=0.002721
#  > iteration=154, best=0.002721
#  > iteration=155, best=0.002721
#  > iteration=156, best=0.002721
#  > iteration=157, best=0.002721
#  > iteration=158, best=0.002721
#  > iteration=159, best=0.002721
#  > iteration=160, best=0.002721
#  > iteration=161, best=0.002721
#  > iteration=162, best=0.002721
#  > iteration=163, best=0.002721
#  > iteration=164, best=0.002721
#  > iteration=165, best=0.002721
#  > iteration=166, best=0.002721
#  > iteration=167, best=0.002721
#  > iteration=168, best=0.002721
#  > iteration=169, best=0.002721
#  > iteration=170, best=0.002721
#  > iteration=171, best=0.002721
#  > iteration=172, best=0.002721
#  > iteration=173, best=0.002721
#  > iteration=174, best=0.002721
#  > iteration=175, best=0.002721
#  > iteration=176, best=0.002721
#  > iteration=177, best=0.002721
#  > iteration=178, best=0.002721
#  > iteration=179, best=0.002721
#  > iteration=180, best=0.002721
#  > iteration=181, best=0.002721
#  > iteration=182, best=0.002721
#  > iteration=183, best=0.002721
#  > iteration=184, best=0.002721
#  > iteration=185, best=0.002721
#  > iteration=186, best=0.002721
#  > iteration=187, best=0.002721
#  > iteration=188, best=0.002721
#  > iteration=189, best=0.002721
#  > iteration=190, best=0.002721
#  > iteration=191, best=0.002721
#  > iteration=192, best=0.002721
#  > iteration=193, best=0.002721
#  > iteration=194, best=0.002721
#  > iteration=195, best=0.002721
#  > iteration=196, best=0.002721
#  > iteration=197, best=0.002721
#  > iteration=198, best=0.002721
#  > iteration=199, best=0.002721
#  > iteration=200, best=0.002721
#  > iteration=201, best=0.002721
#  > iteration=202, best=0.002721
#  > iteration=203, best=0.002721
#  > iteration=204, best=0.002721
#  > iteration=205, best=0.002721
#  > iteration=206, best=0.002721
#  > iteration=207, best=0.002721
#  > iteration=208, best=0.002721
#  > iteration=209, best=0.002721
#  > iteration=210, best=0.002721
#  > iteration=211, best=0.002721
#  > iteration=212, best=0.002721
#  > iteration=213, best=0.002721
#  > iteration=214, best=0.002721
#  > iteration=215, best=0.002721
#  > iteration=216, best=0.002721
#  > iteration=217, best=0.002721
#  > iteration=218, best=0.002721
#  > iteration=219, best=0.002721
#  > iteration=220, best=0.002721
#  > iteration=221, best=0.002721
#  > iteration=222, best=0.002721
#  > iteration=223, best=0.002721
#  > iteration=224, best=0.002721
#  > iteration=225, best=0.002721
#  > iteration=226, best=0.002721
#  > iteration=227, best=0.002721
#  > iteration=228, best=0.002721
#  > iteration=229, best=0.002721
#  > iteration=230, best=0.002721
#  > iteration=231, best=0.002721
#  > iteration=232, best=0.002721
#  > iteration=233, best=0.002721
#  > iteration=234, best=0.002721
#  > iteration=235, best=0.002721
#  > iteration=236, best=0.002721
#  > iteration=237, best=0.002721
#  > iteration=238, best=0.002721
#  > iteration=239, best=0.002721
#  > iteration=240, best=0.002721
#  > iteration=241, best=0.002721
#  > iteration=242, best=0.002721
#  > iteration=243, best=0.002721
#  > iteration=244, best=0.002721
#  > iteration=245, best=0.002721
#  > iteration=246, best=0.002721
#  > iteration=247, best=0.002721
#  > iteration=248, best=0.002721
#  > iteration=249, best=0.002721
#  > iteration=250, best=0.002721
#  > iteration=251, best=0.002721
#  > iteration=252, best=0.002721
#  > iteration=253, best=0.002721
#  > iteration=254, best=0.000303
#  > iteration=255, best=0.000303
#  > iteration=256, best=0.000303
#  > iteration=257, best=0.000303
#  > iteration=258, best=0.000303
#  > iteration=259, best=0.000303
#  > iteration=260, best=0.000303
#  > iteration=261, best=0.000303
#  > iteration=262, best=0.000303
#  > iteration=263, best=0.000303
#  > iteration=264, best=0.000303
#  > iteration=265, best=0.000303
#  > iteration=266, best=0.000303
#  > iteration=267, best=0.000303
#  > iteration=268, best=0.000303
#  > iteration=269, best=0.000303
#  > iteration=270, best=0.000303
#  > iteration=271, best=0.000303
#  > iteration=272, best=0.000303
#  > iteration=273, best=0.000303
#  > iteration=274, best=0.000303
#  > iteration=275, best=0.000303
#  > iteration=276, best=0.000303
#  > iteration=277, best=0.000303
#  > iteration=278, best=0.000303
#  > iteration=279, best=0.000303
#  > iteration=280, best=0.000303
#  > iteration=281, best=0.000303
#  > iteration=282, best=0.000303
#  > iteration=283, best=0.000303
#  > iteration=284, best=0.000303
#  > iteration=285, best=0.000303
#  > iteration=286, best=0.000303
#  > iteration=287, best=0.000303
#  > iteration=288, best=0.000303
#  > iteration=289, best=0.000303
#  > iteration=290, best=0.000303
#  > iteration=291, best=0.000303
#  > iteration=292, best=0.000303
#  > iteration=293, best=0.000303
#  > iteration=294, best=0.000303
#  > iteration=295, best=0.000303
#  > iteration=296, best=0.000303
#  > iteration=297, best=0.000303
#  > iteration=298, best=0.000303
#  > iteration=299, best=0.000303
#  > iteration=300, best=0.000303
#  > iteration=301, best=0.000303
#  > iteration=302, best=0.000303
#  > iteration=303, best=0.000303
#  > iteration=304, best=0.000303
#  > iteration=305, best=0.000303
#  > iteration=306, best=0.000303
#  > iteration=307, best=0.000303
#  > iteration=308, best=0.000303
#  > iteration=309, best=0.000303
#  > iteration=310, best=0.000303
#  > iteration=311, best=0.000303
#  > iteration=312, best=0.000303
#  > iteration=313, best=0.000303
#  > iteration=314, best=0.000303
#  > iteration=315, best=0.000303
#  > iteration=316, best=0.000303
#  > iteration=317, best=0.000303
#  > iteration=318, best=0.000303
#  > iteration=319, best=0.000303
#  > iteration=320, best=0.000303
#  > iteration=321, best=0.000303
#  > iteration=322, best=0.000303
#  > iteration=323, best=0.000303
#  > iteration=324, best=0.000303
#  > iteration=325, best=0.000303
#  > iteration=326, best=0.000303
#  > iteration=327, best=0.000303
#  > iteration=328, best=0.000303
#  > iteration=329, best=0.000303
#  > iteration=330, best=0.000303
#  > iteration=331, best=0.000303
#  > iteration=332, best=0.000303
#  > iteration=333, best=0.000303
#  > iteration=334, best=0.000303
#  > iteration=335, best=0.000303
#  > iteration=336, best=0.000303
#  > iteration=337, best=0.000303
#  > iteration=338, best=0.000303
#  > iteration=339, best=0.000303
#  > iteration=340, best=0.000303
#  > iteration=341, best=0.000303
#  > iteration=342, best=0.000303
#  > iteration=343, best=0.000303
#  > iteration=344, best=0.000303
#  > iteration=345, best=0.000303
#  > iteration=346, best=0.000303
#  > iteration=347, best=0.000303
#  > iteration=348, best=0.000303
#  > iteration=349, best=0.000303
#  > iteration=350, best=0.000303
#  > iteration=351, best=0.000303
#  > iteration=352, best=0.000303
#  > iteration=353, best=0.000303
#  > iteration=354, best=0.000303
#  > iteration=355, best=0.000303
#  > iteration=356, best=0.000303
#  > iteration=357, best=0.000303
#  > iteration=358, best=0.000303
#  > iteration=359, best=0.000303
#  > iteration=360, best=0.000303
#  > iteration=361, best=0.000303
#  > iteration=362, best=0.000303
#  > iteration=363, best=0.000303
#  > iteration=364, best=0.000303
#  > iteration=365, best=0.000303
#  > iteration=366, best=0.000303
#  > iteration=367, best=0.000303
#  > iteration=368, best=0.000303
#  > iteration=369, best=0.000303
#  > iteration=370, best=0.000303
#  > iteration=371, best=0.000303
#  > iteration=372, best=0.000303
#  > iteration=373, best=0.000303
#  > iteration=374, best=0.000303
#  > iteration=375, best=0.000303
#  > iteration=376, best=0.000303
#  > iteration=377, best=0.000303
#  > iteration=378, best=0.000303
#  > iteration=379, best=0.000303
#  > iteration=380, best=0.000303
#  > iteration=381, best=0.000303
#  > iteration=382, best=0.000303
#  > iteration=383, best=0.000303
#  > iteration=384, best=0.000303
#  > iteration=385, best=0.000303
#  > iteration=386, best=0.000303
#  > iteration=387, best=0.000303
#  > iteration=388, best=0.000303
#  > iteration=389, best=0.000303
#  > iteration=390, best=0.000049
#  > iteration=391, best=0.000049
#  > iteration=392, best=0.000049
#  > iteration=393, best=0.000049
#  > iteration=394, best=0.000049
#  > iteration=395, best=0.000042
#  > iteration=396, best=0.000042
#  > iteration=397, best=0.000042
#  > iteration=398, best=0.000042
#  > iteration=399, best=0.000042
#  > iteration=400, best=0.000042
#  > iteration=401, best=0.000042
#  > iteration=402, best=0.000042
#  > iteration=403, best=0.000042
#  > iteration=404, best=0.000042
#  > iteration=405, best=0.000042
#  > iteration=406, best=0.000042
#  > iteration=407, best=0.000042
#  > iteration=408, best=0.000042
#  > iteration=409, best=0.000042
#  > iteration=410, best=0.000042
#  > iteration=411, best=0.000042
#  > iteration=412, best=0.000042
#  > iteration=413, best=0.000042
#  > iteration=414, best=0.000042
#  > iteration=415, best=0.000042
#  > iteration=416, best=0.000042
#  > iteration=417, best=0.000042
#  > iteration=418, best=0.000042
#  > iteration=419, best=0.000042
#  > iteration=420, best=0.000042
#  > iteration=421, best=0.000042
#  > iteration=422, best=0.000042
#  > iteration=423, best=0.000042
#  > iteration=424, best=0.000042
#  > iteration=425, best=0.000042
#  > iteration=426, best=0.000042
#  > iteration=427, best=0.000042
#  > iteration=428, best=0.000042
#  > iteration=429, best=0.000042
#  > iteration=430, best=0.000042
#  > iteration=431, best=0.000042
#  > iteration=432, best=0.000042
#  > iteration=433, best=0.000042
#  > iteration=434, best=0.000042
#  > iteration=435, best=0.000042
#  > iteration=436, best=0.000042
#  > iteration=437, best=0.000042
#  > iteration=438, best=0.000042
#  > iteration=439, best=0.000042
#  > iteration=440, best=0.000042
#  > iteration=441, best=0.000042
#  > iteration=442, best=0.000042
#  > iteration=443, best=0.000042
#  > iteration=444, best=0.000042
#  > iteration=445, best=0.000042
#  > iteration=446, best=0.000042
#  > iteration=447, best=0.000042
#  > iteration=448, best=0.000042
#  > iteration=449, best=0.000042
#  > iteration=450, best=0.000042
#  > iteration=451, best=0.000042
#  > iteration=452, best=0.000042
#  > iteration=453, best=0.000042
#  > iteration=454, best=0.000042
#  > iteration=455, best=0.000042
#  > iteration=456, best=0.000042
#  > iteration=457, best=0.000042
#  > iteration=458, best=0.000042
#  > iteration=459, best=0.000042
#  > iteration=460, best=0.000042
#  > iteration=461, best=0.000042
#  > iteration=462, best=0.000042
#  > iteration=463, best=0.000042
#  > iteration=464, best=0.000042
#  > iteration=465, best=0.000042
#  > iteration=466, best=0.000042
#  > iteration=467, best=0.000042
#  > iteration=468, best=0.000042
#  > iteration=469, best=0.000042
#  > iteration=470, best=0.000042
#  > iteration=471, best=0.000042
#  > iteration=472, best=0.000042
#  > iteration=473, best=0.000042
#  > iteration=474, best=0.000042
#  > iteration=475, best=0.000042
#  > iteration=476, best=0.000042
#  > iteration=477, best=0.000042
#  > iteration=478, best=0.000042
#  > iteration=479, best=0.000042
#  > iteration=480, best=0.000042
#  > iteration=481, best=0.000042
#  > iteration=482, best=0.000042
#  > iteration=483, best=0.000042
#  > iteration=484, best=0.000042
#  > iteration=485, best=0.000042
#  > iteration=486, best=0.000042
#  > iteration=487, best=0.000042
#  > iteration=488, best=0.000042
#  > iteration=489, best=0.000042
#  > iteration=490, best=0.000042
#  > iteration=491, best=0.000042
#  > iteration=492, best=0.000042
#  > iteration=493, best=0.000042
#  > iteration=494, best=0.000042
#  > iteration=495, best=0.000042
#  > iteration=496, best=0.000042
#  > iteration=497, best=0.000042
#  > iteration=498, best=0.000042
#  > iteration=499, best=0.000042
#  > iteration=500, best=0.000042
#  > iteration=501, best=0.000042
#  > iteration=502, best=0.000042
#  > iteration=503, best=0.000042
#  > iteration=504, best=0.000042
#  > iteration=505, best=0.000042
#  > iteration=506, best=0.000042
#  > iteration=507, best=0.000042
#  > iteration=508, best=0.000042
#  > iteration=509, best=0.000042
#  > iteration=510, best=0.000042
#  > iteration=511, best=0.000042
#  > iteration=512, best=0.000042
#  > iteration=513, best=0.000042
#  > iteration=514, best=0.000042
#  > iteration=515, best=0.000042
#  > iteration=516, best=0.000042
#  > iteration=517, best=0.000042
#  > iteration=518, best=0.000042
#  > iteration=519, best=0.000042
#  > iteration=520, best=0.000042
#  > iteration=521, best=0.000042
#  > iteration=522, best=0.000042
#  > iteration=523, best=0.000042
#  > iteration=524, best=0.000042
#  > iteration=525, best=0.000042
#  > iteration=526, best=0.000042
#  > iteration=527, best=0.000042
#  > iteration=528, best=0.000042
#  > iteration=529, best=0.000042
#  > iteration=530, best=0.000042
#  > iteration=531, best=0.000042
#  > iteration=532, best=0.000042
#  > iteration=533, best=0.000015
#  > iteration=534, best=0.000015
#  > iteration=535, best=0.000015
#  > iteration=536, best=0.000015
#  > iteration=537, best=0.000015
#  > iteration=538, best=0.000015
#  > iteration=539, best=0.000015
#  > iteration=540, best=0.000015
#  > iteration=541, best=0.000015
#  > iteration=542, best=0.000015
#  > iteration=543, best=0.000015
#  > iteration=544, best=0.000015
#  > iteration=545, best=0.000015
#  > iteration=546, best=0.000015
#  > iteration=547, best=0.000015
#  > iteration=548, best=0.000015
#  > iteration=549, best=0.000015
#  > iteration=550, best=0.000015
#  > iteration=551, best=0.000015
#  > iteration=552, best=0.000015
#  > iteration=553, best=0.000015
#  > iteration=554, best=0.000015
#  > iteration=555, best=0.000015
#  > iteration=556, best=0.000015
#  > iteration=557, best=0.000015
#  > iteration=558, best=0.000015
#  > iteration=559, best=0.000015
#  > iteration=560, best=0.000015
#  > iteration=561, best=0.000015
#  > iteration=562, best=0.000015
#  > iteration=563, best=0.000015
#  > iteration=564, best=0.000015
#  > iteration=565, best=0.000015
#  > iteration=566, best=0.000015
#  > iteration=567, best=0.000015
#  > iteration=568, best=0.000015
#  > iteration=569, best=0.000015
#  > iteration=570, best=0.000015
#  > iteration=571, best=0.000015
#  > iteration=572, best=0.000015
#  > iteration=573, best=0.000015
#  > iteration=574, best=0.000015
#  > iteration=575, best=0.000015
#  > iteration=576, best=0.000015
#  > iteration=577, best=0.000015
#  > iteration=578, best=0.000015
#  > iteration=579, best=0.000015
#  > iteration=580, best=0.000015
#  > iteration=581, best=0.000015
#  > iteration=582, best=0.000015
#  > iteration=583, best=0.000015
#  > iteration=584, best=0.000015
#  > iteration=585, best=0.000015
#  > iteration=586, best=0.000015
#  > iteration=587, best=0.000015
#  > iteration=588, best=0.000015
#  > iteration=589, best=0.000015
#  > iteration=590, best=0.000015
#  > iteration=591, best=0.000015
#  > iteration=592, best=0.000015
#  > iteration=593, best=0.000015
#  > iteration=594, best=0.000015
#  > iteration=595, best=0.000015
#  > iteration=596, best=0.000015
#  > iteration=597, best=0.000015
#  > iteration=598, best=0.000015
#  > iteration=599, best=0.000015
#  > iteration=600, best=0.000015
#  > iteration=601, best=0.000015
#  > iteration=602, best=0.000015
#  > iteration=603, best=0.000015
#  > iteration=604, best=0.000015
#  > iteration=605, best=0.000015
#  > iteration=606, best=0.000015
#  > iteration=607, best=0.000015
#  > iteration=608, best=0.000015
#  > iteration=609, best=0.000015
#  > iteration=610, best=0.000015
#  > iteration=611, best=0.000015
#  > iteration=612, best=0.000015
#  > iteration=613, best=0.000015
#  > iteration=614, best=0.000015
#  > iteration=615, best=0.000015
#  > iteration=616, best=0.000015
#  > iteration=617, best=0.000015
#  > iteration=618, best=0.000015
#  > iteration=619, best=0.000015
#  > iteration=620, best=0.000015
#  > iteration=621, best=0.000015
#  > iteration=622, best=0.000015
#  > iteration=623, best=0.000015
#  > iteration=624, best=0.000015
#  > iteration=625, best=0.000015
#  > iteration=626, best=0.000015
#  > iteration=627, best=0.000015
#  > iteration=628, best=0.000015
#  > iteration=629, best=0.000015
#  > iteration=630, best=0.000015
#  > iteration=631, best=0.000015
#  > iteration=632, best=0.000015
#  > iteration=633, best=0.000015
#  > iteration=634, best=0.000015
#  > iteration=635, best=0.000015
#  > iteration=636, best=0.000015
#  > iteration=637, best=0.000015
#  > iteration=638, best=0.000015
#  > iteration=639, best=0.000015
#  > iteration=640, best=0.000015
#  > iteration=641, best=0.000015
#  > iteration=642, best=0.000015
#  > iteration=643, best=0.000015
#  > iteration=644, best=0.000015
#  > iteration=645, best=0.000015
#  > iteration=646, best=0.000015
#  > iteration=647, best=0.000015
#  > iteration=648, best=0.000015
#  > iteration=649, best=0.000015
#  > iteration=650, best=0.000015
#  > iteration=651, best=0.000015
#  > iteration=652, best=0.000015
#  > iteration=653, best=0.000015
#  > iteration=654, best=0.000015
#  > iteration=655, best=0.000015
#  > iteration=656, best=0.000015
#  > iteration=657, best=0.000015
#  > iteration=658, best=0.000015
#  > iteration=659, best=0.000015
#  > iteration=660, best=0.000015
#  > iteration=661, best=0.000015
#  > iteration=662, best=0.000015
#  > iteration=663, best=0.000015
#  > iteration=664, best=0.000015
#  > iteration=665, best=0.000015
#  > iteration=666, best=0.000015
#  > iteration=667, best=0.000015
#  > iteration=668, best=0.000015
#  > iteration=669, best=0.000015
#  > iteration=670, best=0.000015
#  > iteration=671, best=0.000015
#  > iteration=672, best=0.000015
#  > iteration=673, best=0.000015
#  > iteration=674, best=0.000015
#  > iteration=675, best=0.000015
#  > iteration=676, best=0.000015
#  > iteration=677, best=0.000015
#  > iteration=678, best=0.000015
#  > iteration=679, best=0.000015
#  > iteration=680, best=0.000015
#  > iteration=681, best=0.000015
#  > iteration=682, best=0.000015
#  > iteration=683, best=0.000015
#  > iteration=684, best=0.000015
#  > iteration=685, best=0.000015
#  > iteration=686, best=0.000015
#  > iteration=687, best=0.000015
#  > iteration=688, best=0.000015
#  > iteration=689, best=0.000015
#  > iteration=690, best=0.000015
#  > iteration=691, best=0.000015
#  > iteration=692, best=0.000015
#  > iteration=693, best=0.000015
#  > iteration=694, best=0.000015
#  > iteration=695, best=0.000015
#  > iteration=696, best=0.000011
#  > iteration=697, best=0.000011
#  > iteration=698, best=0.000011
#  > iteration=699, best=0.000011
#  > iteration=700, best=0.000011
#  > iteration=701, best=0.000011
#  > iteration=702, best=0.000011
#  > iteration=703, best=0.000011
#  > iteration=704, best=0.000011
#  > iteration=705, best=0.000011
#  > iteration=706, best=0.000011
#  > iteration=707, best=0.000011
#  > iteration=708, best=0.000011
#  > iteration=709, best=0.000011
#  > iteration=710, best=0.000011
#  > iteration=711, best=0.000011
#  > iteration=712, best=0.000011
#  > iteration=713, best=0.000011
#  > iteration=714, best=0.000001
#  > iteration=715, best=0.000000
#  > iteration=716, best=0.000000
#  > iteration=717, best=0.000000
#  > iteration=718, best=0.000000
#  > iteration=719, best=0.000000
#  > iteration=720, best=0.000000
#  > iteration=721, best=0.000000
#  > iteration=722, best=0.000000
#  > iteration=723, best=0.000000
#  > iteration=724, best=0.000000
#  > iteration=725, best=0.000000
#  > iteration=726, best=0.000000
#  > iteration=727, best=0.000000
#  > iteration=728, best=0.000000
#  > iteration=729, best=0.000000
#  > iteration=730, best=0.000000
#  > iteration=731, best=0.000000
#  > iteration=732, best=0.000000
#  > iteration=733, best=0.000000
#  > iteration=734, best=0.000000
#  > iteration=735, best=0.000000
#  > iteration=736, best=0.000000
#  > iteration=737, best=0.000000
#  > iteration=738, best=0.000000
#  > iteration=739, best=0.000000
#  > iteration=740, best=0.000000
#  > iteration=741, best=0.000000
#  > iteration=742, best=0.000000
#  > iteration=743, best=0.000000
#  > iteration=744, best=0.000000
#  > iteration=745, best=0.000000
#  > iteration=746, best=0.000000
#  > iteration=747, best=0.000000
#  > iteration=748, best=0.000000
#  > iteration=749, best=0.000000
#  > iteration=750, best=0.000000
#  > iteration=751, best=0.000000
#  > iteration=752, best=0.000000
#  > iteration=753, best=0.000000
#  > iteration=754, best=0.000000
#  > iteration=755, best=0.000000
#  > iteration=756, best=0.000000
#  > iteration=757, best=0.000000
#  > iteration=758, best=0.000000
#  > iteration=759, best=0.000000
#  > iteration=760, best=0.000000
#  > iteration=761, best=0.000000
#  > iteration=762, best=0.000000
#  > iteration=763, best=0.000000
#  > iteration=764, best=0.000000
#  > iteration=765, best=0.000000
#  > iteration=766, best=0.000000
#  > iteration=767, best=0.000000
#  > iteration=768, best=0.000000
#  > iteration=769, best=0.000000
#  > iteration=770, best=0.000000
#  > iteration=771, best=0.000000
#  > iteration=772, best=0.000000
#  > iteration=773, best=0.000000
#  > iteration=774, best=0.000000
#  > iteration=775, best=0.000000
#  > iteration=776, best=0.000000
#  > iteration=777, best=0.000000
#  > iteration=778, best=0.000000
#  > iteration=779, best=0.000000
#  > iteration=780, best=0.000000
#  > iteration=781, best=0.000000
#  > iteration=782, best=0.000000
#  > iteration=783, best=0.000000
#  > iteration=784, best=0.000000
#  > iteration=785, best=0.000000
#  > iteration=786, best=0.000000
#  > iteration=787, best=0.000000
#  > iteration=788, best=0.000000
#  > iteration=789, best=0.000000
#  > iteration=790, best=0.000000
#  > iteration=791, best=0.000000
#  > iteration=792, best=0.000000
#  > iteration=793, best=0.000000
#  > iteration=794, best=0.000000
#  > iteration=795, best=0.000000
#  > iteration=796, best=0.000000
#  > iteration=797, best=0.000000
#  > iteration=798, best=0.000000
#  > iteration=799, best=0.000000
#  > iteration=800, best=0.000000
#  > iteration=801, best=0.000000
#  > iteration=802, best=0.000000
#  > iteration=803, best=0.000000
#  > iteration=804, best=0.000000
#  > iteration=805, best=0.000000
#  > iteration=806, best=0.000000
#  > iteration=807, best=0.000000
#  > iteration=808, best=0.000000
#  > iteration=809, best=0.000000
#  > iteration=810, best=0.000000
#  > iteration=811, best=0.000000
#  > iteration=812, best=0.000000
#  > iteration=813, best=0.000000
#  > iteration=814, best=0.000000
#  > iteration=815, best=0.000000
#  > iteration=816, best=0.000000
#  > iteration=817, best=0.000000
#  > iteration=818, best=0.000000
#  > iteration=819, best=0.000000
#  > iteration=820, best=0.000000
#  > iteration=821, best=0.000000
#  > iteration=822, best=0.000000
#  > iteration=823, best=0.000000
#  > iteration=824, best=0.000000
#  > iteration=825, best=0.000000
#  > iteration=826, best=0.000000
#  > iteration=827, best=0.000000
#  > iteration=828, best=0.000000
#  > iteration=829, best=0.000000
#  > iteration=830, best=0.000000
#  > iteration=831, best=0.000000
#  > iteration=832, best=0.000000
#  > iteration=833, best=0.000000
#  > iteration=834, best=0.000000
#  > iteration=835, best=0.000000
#  > iteration=836, best=0.000000
#  > iteration=837, best=0.000000
#  > iteration=838, best=0.000000
#  > iteration=839, best=0.000000
#  > iteration=840, best=0.000000
#  > iteration=841, best=0.000000
#  > iteration=842, best=0.000000
#  > iteration=843, best=0.000000
#  > iteration=844, best=0.000000
#  > iteration=845, best=0.000000
#  > iteration=846, best=0.000000
#  > iteration=847, best=0.000000
#  > iteration=848, best=0.000000
#  > iteration=849, best=0.000000
#  > iteration=850, best=0.000000
#  > iteration=851, best=0.000000
#  > iteration=852, best=0.000000
#  > iteration=853, best=0.000000
#  > iteration=854, best=0.000000
#  > iteration=855, best=0.000000
#  > iteration=856, best=0.000000
#  > iteration=857, best=0.000000
#  > iteration=858, best=0.000000
#  > iteration=859, best=0.000000
#  > iteration=860, best=0.000000
#  > iteration=861, best=0.000000
#  > iteration=862, best=0.000000
#  > iteration=863, best=0.000000
#  > iteration=864, best=0.000000
#  > iteration=865, best=0.000000
#  > iteration=866, best=0.000000
#  > iteration=867, best=0.000000
#  > iteration=868, best=0.000000
#  > iteration=869, best=0.000000
#  > iteration=870, best=0.000000
#  > iteration=871, best=0.000000
#  > iteration=872, best=0.000000
#  > iteration=873, best=0.000000
#  > iteration=874, best=0.000000
#  > iteration=875, best=0.000000
#  > iteration=876, best=0.000000
#  > iteration=877, best=0.000000
#  > iteration=878, best=0.000000
#  > iteration=879, best=0.000000
#  > iteration=880, best=0.000000
#  > iteration=881, best=0.000000
#  > iteration=882, best=0.000000
#  > iteration=883, best=0.000000
#  > iteration=884, best=0.000000
#  > iteration=885, best=0.000000
#  > iteration=886, best=0.000000
#  > iteration=887, best=0.000000
#  > iteration=888, best=0.000000
#  > iteration=889, best=0.000000
#  > iteration=890, best=0.000000
#  > iteration=891, best=0.000000
#  > iteration=892, best=0.000000
#  > iteration=893, best=0.000000
#  > iteration=894, best=0.000000
#  > iteration=895, best=0.000000
#  > iteration=896, best=0.000000
#  > iteration=897, best=0.000000
#  > iteration=898, best=0.000000
#  > iteration=899, best=0.000000
#  > iteration=900, best=0.000000
#  > iteration=901, best=0.000000
#  > iteration=902, best=0.000000
#  > iteration=903, best=0.000000
#  > iteration=904, best=0.000000
#  > iteration=905, best=0.000000
#  > iteration=906, best=0.000000
#  > iteration=907, best=0.000000
#  > iteration=908, best=0.000000
#  > iteration=909, best=0.000000
#  > iteration=910, best=0.000000
#  > iteration=911, best=0.000000
#  > iteration=912, best=0.000000
#  > iteration=913, best=0.000000
#  > iteration=914, best=0.000000
#  > iteration=915, best=0.000000
#  > iteration=916, best=0.000000
#  > iteration=917, best=0.000000
#  > iteration=918, best=0.000000
#  > iteration=919, best=0.000000
#  > iteration=920, best=0.000000
#  > iteration=921, best=0.000000
#  > iteration=922, best=0.000000
#  > iteration=923, best=0.000000
#  > iteration=924, best=0.000000
#  > iteration=925, best=0.000000
#  > iteration=926, best=0.000000
#  > iteration=927, best=0.000000
#  > iteration=928, best=0.000000
#  > iteration=929, best=0.000000
#  > iteration=930, best=0.000000
#  > iteration=931, best=0.000000
#  > iteration=932, best=0.000000
#  > iteration=933, best=0.000000
#  > iteration=934, best=0.000000
#  > iteration=935, best=0.000000
#  > iteration=936, best=0.000000
#  > iteration=937, best=0.000000
#  > iteration=938, best=0.000000
#  > iteration=939, best=0.000000
#  > iteration=940, best=0.000000
#  > iteration=941, best=0.000000
#  > iteration=942, best=0.000000
#  > iteration=943, best=0.000000
#  > iteration=944, best=0.000000
#  > iteration=945, best=0.000000
#  > iteration=946, best=0.000000
#  > iteration=947, best=0.000000
#  > iteration=948, best=0.000000
#  > iteration=949, best=0.000000
#  > iteration=950, best=0.000000
#  > iteration=951, best=0.000000
#  > iteration=952, best=0.000000
#  > iteration=953, best=0.000000
#  > iteration=954, best=0.000000
#  > iteration=955, best=0.000000
#  > iteration=956, best=0.000000
#  > iteration=957, best=0.000000
#  > iteration=958, best=0.000000
#  > iteration=959, best=0.000000
#  > iteration=960, best=0.000000
#  > iteration=961, best=0.000000
#  > iteration=962, best=0.000000
#  > iteration=963, best=0.000000
#  > iteration=964, best=0.000000
#  > iteration=965, best=0.000000
#  > iteration=966, best=0.000000
#  > iteration=967, best=0.000000
#  > iteration=968, best=0.000000
#  > iteration=969, best=0.000000
#  > iteration=970, best=0.000000
#  > iteration=971, best=0.000000
#  > iteration=972, best=0.000000
#  > iteration=973, best=0.000000
#  > iteration=974, best=0.000000
#  > iteration=975, best=0.000000
#  > iteration=976, best=0.000000
#  > iteration=977, best=0.000000
#  > iteration=978, best=0.000000
#  > iteration=979, best=0.000000
#  > iteration=980, best=0.000000
#  > iteration=981, best=0.000000
#  > iteration=982, best=0.000000
#  > iteration=983, best=0.000000
#  > iteration=984, best=0.000000
#  > iteration=985, best=0.000000
#  > iteration=986, best=0.000000
#  > iteration=987, best=0.000000
#  > iteration=988, best=0.000000
#  > iteration=989, best=0.000000
#  > iteration=990, best=0.000000
#  > iteration=991, best=0.000000
#  > iteration=992, best=0.000000
#  > iteration=993, best=0.000000
#  > iteration=994, best=0.000000
#  > iteration=995, best=0.000000
#  > iteration=996, best=0.000000
#  > iteration=997, best=0.000000
#  > iteration=998, best=0.000000
#  > iteration=999, best=0.000000
#  > iteration=1000, best=0.000000
# Done. Best Solution: c=0.000000, v=[6.917207186524221e-05, -0.0001723049609088298]
