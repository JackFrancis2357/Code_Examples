# %%
"""
Variable Neighborhood Search
"""


def iif(condition, true_part, false_part):
    return (condition and [true_part] or [false_part])[0]


def euc_2d(c1, c2):
    import math

    return round(math.sqrt((c1[0] - c2[0]) ** 2 + (c1[1] - c2[1]) ** 2))


def cost(permutation, cities):
    distance = 0
    for i in range(0, len(permutation)):
        c1 = permutation[i]
        c2 = permutation[iif(i == len(permutation) - 1, 0, i + 1)]
        distance += euc_2d(cities[c1], cities[c2])
    return distance


def random_permutation(cities):
    import random

    perm = range(len(cities))
    for i in perm:
        r = random.randrange(len(perm) - i) + i
        perm[r], perm[i] = perm[i], perm[r]
    return perm


def stochastic_two_opt(parent):
    from random import randrange

    perm = parent
    c1, c2 = randrange(len(perm)), randrange(len(perm))
    exclude = [
        c1,
        iif(c1 == 0, len(perm) - 1, c1 - 1),
        iif(c1 == len(perm) - 1, 0, c1 + 1)
    ]
    while c2 in exclude:
        c2 = randrange(len(perm))
    if c2 < c1:
        c1, c2 = c2, c1
    r = perm[c1:c2]
    r.reverse()
    perm[c1:c2] = r
    return perm


def local_search(best, cities, max_no_improve, neighborhood):
    count = 0
    while count < max_no_improve:
        candidate = {'vector': best['vector'][:]}
        for i in xrange(neighborhood):
            stochastic_two_opt(candidate['vector'])
        candidate['cost'] = cost(candidate['vector'], cities)
        if candidate['cost'] < best['cost']:
            count, best = 0, candidate
        else:
            count += 1
    return best


def search(cities, neighborhoods, max_no_improv, max_no_improv_ls):
    best = {'vector': random_permutation(cities)}
    best['cost'] = cost(best['vector'], cities)
    iteration, count = 0, 0
    while count < max_no_improv:
        for neigh in neighborhoods:
            candidate = {'vector': best['vector'][:]}
            for i in xrange(neigh):
                stochastic_two_opt(candidate['vector'])
            candidate['cost'] = cost(candidate['vector'], cities)
            candidate = local_search(candidate, cities, max_no_improv_ls, neigh)
            print " > iteration %d, neigh=%d, candicate=%f, best=%f" % (iteration + 1, neigh, candidate['cost'], best['cost'])
            iteration += 1
            if candidate['cost'] < best['cost']:
                best, count = candidate, 0
                print "New best, restarting neighborhood search."
                break
            else:
                count += 1
    return best


def main():
    # problem configuration
    berlin52 = [[565, 575], [25, 185], [345, 750], [945, 685], [845, 655],
                [880, 660], [25, 230], [525, 1000], [580, 1175], [650, 1130], [1605, 620],
                [1220, 580], [1465, 200], [1530, 5], [845, 680], [725, 370], [145, 665],
                [415, 635], [510, 875], [560, 365], [300, 465], [520, 585], [480, 415],
                [835, 625], [975, 580], [1215, 245], [1320, 315], [1250, 400], [660, 180],
                [410, 250], [420, 555], [575, 665], [1150, 1160], [700, 580], [685, 595],
                [685, 610], [770, 610], [795, 645], [720, 635], [760, 650], [475, 960],
                [95, 260], [875, 920], [700, 500], [555, 815], [830, 485], [1170, 65],
                [830, 610], [605, 625], [595, 360], [1340, 725], [1740, 245]]
    # algorithm configuration
    max_no_improv = 50
    max_no_improv_ls = 70
    neighborhoods = range(1, 20)
    # execute the algorithm
    best = search(berlin52, neighborhoods, max_no_improv, max_no_improv_ls)
    print 'Done. Best Solution: c=%d, v=%s' % (best['cost'], str(best['vector']))


if __name__ == "__main__":
    main()
# Out:
#  > iteration 1, neigh=1, candicate=15549.000000, best=29147.000000
# New best, restarting neighborhood search.
#  > iteration 2, neigh=1, candicate=11163.000000, best=15549.000000
# New best, restarting neighborhood search.
#  > iteration 3, neigh=1, candicate=11308.000000, best=11163.000000
#  > iteration 4, neigh=2, candicate=11610.000000, best=11163.000000
#  > iteration 5, neigh=3, candicate=13903.000000, best=11163.000000
#  > iteration 6, neigh=4, candicate=13044.000000, best=11163.000000
#  > iteration 7, neigh=5, candicate=15203.000000, best=11163.000000
#  > iteration 8, neigh=6, candicate=14285.000000, best=11163.000000
#  > iteration 9, neigh=7, candicate=15560.000000, best=11163.000000
#  > iteration 10, neigh=8, candicate=15503.000000, best=11163.000000
#  > iteration 11, neigh=9, candicate=20110.000000, best=11163.000000
#  > iteration 12, neigh=10, candicate=17079.000000, best=11163.000000
#  > iteration 13, neigh=11, candicate=18198.000000, best=11163.000000
#  > iteration 14, neigh=12, candicate=18617.000000, best=11163.000000
#  > iteration 15, neigh=13, candicate=20327.000000, best=11163.000000
#  > iteration 16, neigh=14, candicate=16560.000000, best=11163.000000
#  > iteration 17, neigh=15, candicate=22193.000000, best=11163.000000
#  > iteration 18, neigh=16, candicate=21704.000000, best=11163.000000
#  > iteration 19, neigh=17, candicate=22962.000000, best=11163.000000
#  > iteration 20, neigh=18, candicate=20793.000000, best=11163.000000
#  > iteration 21, neigh=19, candicate=19128.000000, best=11163.000000
#  > iteration 22, neigh=1, candicate=10053.000000, best=11163.000000
# New best, restarting neighborhood search.
#  > iteration 23, neigh=1, candicate=10053.000000, best=10053.000000
#  > iteration 24, neigh=2, candicate=10979.000000, best=10053.000000
#  > iteration 25, neigh=3, candicate=12320.000000, best=10053.000000
#  > iteration 26, neigh=4, candicate=11530.000000, best=10053.000000
#  > iteration 27, neigh=5, candicate=14093.000000, best=10053.000000
#  > iteration 28, neigh=6, candicate=14650.000000, best=10053.000000
#  > iteration 29, neigh=7, candicate=16658.000000, best=10053.000000
#  > iteration 30, neigh=8, candicate=13912.000000, best=10053.000000
#  > iteration 31, neigh=9, candicate=15741.000000, best=10053.000000
#  > iteration 32, neigh=10, candicate=18260.000000, best=10053.000000
#  > iteration 33, neigh=11, candicate=15971.000000, best=10053.000000
#  > iteration 34, neigh=12, candicate=17097.000000, best=10053.000000
#  > iteration 35, neigh=13, candicate=18137.000000, best=10053.000000
#  > iteration 36, neigh=14, candicate=17871.000000, best=10053.000000
#  > iteration 37, neigh=15, candicate=16923.000000, best=10053.000000
#  > iteration 38, neigh=16, candicate=17907.000000, best=10053.000000
#  > iteration 39, neigh=17, candicate=20100.000000, best=10053.000000
#  > iteration 40, neigh=18, candicate=21066.000000, best=10053.000000
#  > iteration 41, neigh=19, candicate=19236.000000, best=10053.000000
#  > iteration 42, neigh=1, candicate=10208.000000, best=10053.000000
#  > iteration 43, neigh=2, candicate=11088.000000, best=10053.000000
#  > iteration 44, neigh=3, candicate=12350.000000, best=10053.000000
#  > iteration 45, neigh=4, candicate=13099.000000, best=10053.000000
#  > iteration 46, neigh=5, candicate=14205.000000, best=10053.000000
#  > iteration 47, neigh=6, candicate=14362.000000, best=10053.000000
#  > iteration 48, neigh=7, candicate=16043.000000, best=10053.000000
#  > iteration 49, neigh=8, candicate=13067.000000, best=10053.000000
#  > iteration 50, neigh=9, candicate=15491.000000, best=10053.000000
#  > iteration 51, neigh=10, candicate=14020.000000, best=10053.000000
#  > iteration 52, neigh=11, candicate=16492.000000, best=10053.000000
#  > iteration 53, neigh=12, candicate=17004.000000, best=10053.000000
#  > iteration 54, neigh=13, candicate=18875.000000, best=10053.000000
#  > iteration 55, neigh=14, candicate=19444.000000, best=10053.000000
#  > iteration 56, neigh=15, candicate=18566.000000, best=10053.000000
#  > iteration 57, neigh=16, candicate=16727.000000, best=10053.000000
#  > iteration 58, neigh=17, candicate=22424.000000, best=10053.000000
#  > iteration 59, neigh=18, candicate=18488.000000, best=10053.000000
#  > iteration 60, neigh=19, candicate=20573.000000, best=10053.000000
#  > iteration 61, neigh=1, candicate=9950.000000, best=10053.000000
# New best, restarting neighborhood search.
#  > iteration 62, neigh=1, candicate=9709.000000, best=9950.000000
# New best, restarting neighborhood search.
#  > iteration 63, neigh=1, candicate=9898.000000, best=9709.000000
#  > iteration 64, neigh=2, candicate=11069.000000, best=9709.000000
#  > iteration 65, neigh=3, candicate=12100.000000, best=9709.000000
#  > iteration 66, neigh=4, candicate=13992.000000, best=9709.000000
#  > iteration 67, neigh=5, candicate=12191.000000, best=9709.000000
#  > iteration 68, neigh=6, candicate=15451.000000, best=9709.000000
#  > iteration 69, neigh=7, candicate=14344.000000, best=9709.000000
#  > iteration 70, neigh=8, candicate=13962.000000, best=9709.000000
#  > iteration 71, neigh=9, candicate=15898.000000, best=9709.000000
#  > iteration 72, neigh=10, candicate=15794.000000, best=9709.000000
#  > iteration 73, neigh=11, candicate=17065.000000, best=9709.000000
#  > iteration 74, neigh=12, candicate=19444.000000, best=9709.000000
#  > iteration 75, neigh=13, candicate=14464.000000, best=9709.000000
#  > iteration 76, neigh=14, candicate=18575.000000, best=9709.000000
#  > iteration 77, neigh=15, candicate=20172.000000, best=9709.000000
#  > iteration 78, neigh=16, candicate=20326.000000, best=9709.000000
#  > iteration 79, neigh=17, candicate=21447.000000, best=9709.000000
#  > iteration 80, neigh=18, candicate=20881.000000, best=9709.000000
#  > iteration 81, neigh=19, candicate=19018.000000, best=9709.000000
#  > iteration 82, neigh=1, candicate=9743.000000, best=9709.000000
#  > iteration 83, neigh=2, candicate=11449.000000, best=9709.000000
#  > iteration 84, neigh=3, candicate=12563.000000, best=9709.000000
#  > iteration 85, neigh=4, candicate=10875.000000, best=9709.000000
#  > iteration 86, neigh=5, candicate=13432.000000, best=9709.000000
#  > iteration 87, neigh=6, candicate=13875.000000, best=9709.000000
#  > iteration 88, neigh=7, candicate=14692.000000, best=9709.000000
#  > iteration 89, neigh=8, candicate=16297.000000, best=9709.000000
#  > iteration 90, neigh=9, candicate=14861.000000, best=9709.000000
#  > iteration 91, neigh=10, candicate=16921.000000, best=9709.000000
#  > iteration 92, neigh=11, candicate=16545.000000, best=9709.000000
#  > iteration 93, neigh=12, candicate=16271.000000, best=9709.000000
#  > iteration 94, neigh=13, candicate=19048.000000, best=9709.000000
#  > iteration 95, neigh=14, candicate=17120.000000, best=9709.000000
#  > iteration 96, neigh=15, candicate=16262.000000, best=9709.000000
#  > iteration 97, neigh=16, candicate=18547.000000, best=9709.000000
#  > iteration 98, neigh=17, candicate=18173.000000, best=9709.000000
#  > iteration 99, neigh=18, candicate=21618.000000, best=9709.000000
#  > iteration 100, neigh=19, candicate=17247.000000, best=9709.000000
#  > iteration 101, neigh=1, candicate=9020.000000, best=9709.000000
# New best, restarting neighborhood search.
#  > iteration 102, neigh=1, candicate=9440.000000, best=9020.000000
#  > iteration 103, neigh=2, candicate=11414.000000, best=9020.000000
#  > iteration 104, neigh=3, candicate=12522.000000, best=9020.000000
#  > iteration 105, neigh=4, candicate=12783.000000, best=9020.000000
#  > iteration 106, neigh=5, candicate=13475.000000, best=9020.000000
#  > iteration 107, neigh=6, candicate=13681.000000, best=9020.000000
#  > iteration 108, neigh=7, candicate=13524.000000, best=9020.000000
#  > iteration 109, neigh=8, candicate=14342.000000, best=9020.000000
#  > iteration 110, neigh=9, candicate=13611.000000, best=9020.000000
#  > iteration 111, neigh=10, candicate=15358.000000, best=9020.000000
#  > iteration 112, neigh=11, candicate=17929.000000, best=9020.000000
#  > iteration 113, neigh=12, candicate=16730.000000, best=9020.000000
#  > iteration 114, neigh=13, candicate=16570.000000, best=9020.000000
#  > iteration 115, neigh=14, candicate=15886.000000, best=9020.000000
#  > iteration 116, neigh=15, candicate=17434.000000, best=9020.000000
#  > iteration 117, neigh=16, candicate=19526.000000, best=9020.000000
#  > iteration 118, neigh=17, candicate=17960.000000, best=9020.000000
#  > iteration 119, neigh=18, candicate=21101.000000, best=9020.000000
#  > iteration 120, neigh=19, candicate=17435.000000, best=9020.000000
#  > iteration 121, neigh=1, candicate=8819.000000, best=9020.000000
# New best, restarting neighborhood search.
#  > iteration 122, neigh=1, candicate=10233.000000, best=8819.000000
#  > iteration 123, neigh=2, candicate=9335.000000, best=8819.000000
#  > iteration 124, neigh=3, candicate=10266.000000, best=8819.000000
#  > iteration 125, neigh=4, candicate=12515.000000, best=8819.000000
#  > iteration 126, neigh=5, candicate=13006.000000, best=8819.000000
#  > iteration 127, neigh=6, candicate=13810.000000, best=8819.000000
#  > iteration 128, neigh=7, candicate=13017.000000, best=8819.000000
#  > iteration 129, neigh=8, candicate=14590.000000, best=8819.000000
#  > iteration 130, neigh=9, candicate=14499.000000, best=8819.000000
#  > iteration 131, neigh=10, candicate=15298.000000, best=8819.000000
#  > iteration 132, neigh=11, candicate=14743.000000, best=8819.000000
#  > iteration 133, neigh=12, candicate=17631.000000, best=8819.000000
#  > iteration 134, neigh=13, candicate=16770.000000, best=8819.000000
#  > iteration 135, neigh=14, candicate=22321.000000, best=8819.000000
#  > iteration 136, neigh=15, candicate=17695.000000, best=8819.000000
#  > iteration 137, neigh=16, candicate=18150.000000, best=8819.000000
#  > iteration 138, neigh=17, candicate=19446.000000, best=8819.000000
#  > iteration 139, neigh=18, candicate=19998.000000, best=8819.000000
#  > iteration 140, neigh=19, candicate=21278.000000, best=8819.000000
#  > iteration 141, neigh=1, candicate=8832.000000, best=8819.000000
#  > iteration 142, neigh=2, candicate=9319.000000, best=8819.000000
#  > iteration 143, neigh=3, candicate=11339.000000, best=8819.000000
#  > iteration 144, neigh=4, candicate=12855.000000, best=8819.000000
#  > iteration 145, neigh=5, candicate=12505.000000, best=8819.000000
#  > iteration 146, neigh=6, candicate=12803.000000, best=8819.000000
#  > iteration 147, neigh=7, candicate=13118.000000, best=8819.000000
#  > iteration 148, neigh=8, candicate=17051.000000, best=8819.000000
#  > iteration 149, neigh=9, candicate=15133.000000, best=8819.000000
#  > iteration 150, neigh=10, candicate=13157.000000, best=8819.000000
#  > iteration 151, neigh=11, candicate=15750.000000, best=8819.000000
#  > iteration 152, neigh=12, candicate=14856.000000, best=8819.000000
#  > iteration 153, neigh=13, candicate=15907.000000, best=8819.000000
#  > iteration 154, neigh=14, candicate=18020.000000, best=8819.000000
#  > iteration 155, neigh=15, candicate=17572.000000, best=8819.000000
#  > iteration 156, neigh=16, candicate=18780.000000, best=8819.000000
#  > iteration 157, neigh=17, candicate=21260.000000, best=8819.000000
#  > iteration 158, neigh=18, candicate=16941.000000, best=8819.000000
#  > iteration 159, neigh=19, candicate=20178.000000, best=8819.000000
#  > iteration 160, neigh=1, candicate=8909.000000, best=8819.000000
#  > iteration 161, neigh=2, candicate=10373.000000, best=8819.000000
#  > iteration 162, neigh=3, candicate=10912.000000, best=8819.000000
#  > iteration 163, neigh=4, candicate=11647.000000, best=8819.000000
#  > iteration 164, neigh=5, candicate=16973.000000, best=8819.000000
#  > iteration 165, neigh=6, candicate=15217.000000, best=8819.000000
#  > iteration 166, neigh=7, candicate=12089.000000, best=8819.000000
#  > iteration 167, neigh=8, candicate=11043.000000, best=8819.000000
#  > iteration 168, neigh=9, candicate=14505.000000, best=8819.000000
#  > iteration 169, neigh=10, candicate=14303.000000, best=8819.000000
#  > iteration 170, neigh=11, candicate=18019.000000, best=8819.000000
#  > iteration 171, neigh=12, candicate=16858.000000, best=8819.000000
#  > iteration 172, neigh=13, candicate=16959.000000, best=8819.000000
#  > iteration 173, neigh=14, candicate=18460.000000, best=8819.000000
#  > iteration 174, neigh=15, candicate=18094.000000, best=8819.000000
#  > iteration 175, neigh=16, candicate=18986.000000, best=8819.000000
#  > iteration 176, neigh=17, candicate=15886.000000, best=8819.000000
#  > iteration 177, neigh=18, candicate=22019.000000, best=8819.000000
#  > iteration 178, neigh=19, candicate=19464.000000, best=8819.000000
# Done. Best Solution: c=8819, v=[10, 27, 11, 50, 24, 14, 4, 23, 37, 39, 38, 36, 45, 43, 35, 31, 17, 30, 20, 29, 1, 6, 41, 16, 2, 44, 18, 40, 7, 9, 8, 32, 42, 3, 5, 47, 33, 34, 48, 0, 21, 22, 19, 49, 15, 28, 46, 25, 26, 12, 13, 51]
